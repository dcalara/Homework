# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 653

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
query_url = "http://api.openweathermap.org/data/2.5/weather?q={}&appid={}"

# Create lists for columns
clouds = []
country = []
dt = []
humidity = []
lat = []
lon= []
temp_max = []
speed = []
# Record counter
record_count = 0

print("Beginning Data Retrieval")
print("-------------------------") 

# Loop through the list of cities and perform a request for data on each
for city in cities:

    try:
        response = requests.get(query_url.format(city, api_key)).json()
       
        # Count records
        record_count = record_count + 1
        
        print(f"Processing Record {record_count} | {city}")
        
        # Add data to lists
        
        clouds.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        dt.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        speed.append(response['wind']['speed'])
        
    except:
        print('City not found..Skipping.')
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 | vaitupu
# City not found..Skipping.
# Processing Record 2 | wasilla
# Processing Record 3 | hilo
# Processing Record 4 | cape town
# Processing Record 5 | busselton
# Processing Record 6 | carnarvon
# Processing Record 7 | haines junction
# Processing Record 8 | tasiilaq
# Processing Record 9 | port keats
# Processing Record 10 | trincomalee
# Processing Record 11 | barra
# Processing Record 12 | port hardy
# Processing Record 13 | hithadhoo
# Processing Record 14 | bengkulu
# City not found..Skipping.
# Processing Record 15 | jalu
# Processing Record 16 | rikitea
# Processing Record 17 | bredasdorp
# Processing Record 18 | albany
# Processing Record 19 | likasi
# Processing Record 20 | ushuaia
# Processing Record 21 | roald
# Processing Record 22 | bubaque
# Processing Record 23 | mahenge
# Processing Record 24 | port-cartier
# Processing Record 25 | lebu
# Processing Record 26 | alice springs
# Processing Record 27 | jiroft
# City not found..Skipping.
# Processing Record 28 | balikpapan
# Processing Record 29 | namatanai
# Processing Record 30 | mar del plata
# Processing Record 31 | sabang
# Processing Record 32 | punta arenas
# Processing Record 33 | mahebourg
# Processing Record 34 | palmer
# Processing Record 35 | jamestown
# Processing Record 36 | qaanaaq
# Processing Record 37 | wa
# City not found..Skipping.
# Processing Record 38 | norman wells
# Processing Record 39 | urucurituba
# City not found..Skipping.
# Processing Record 40 | barbar
# City not found..Skipping.
# Processing Record 41 | grindavik
# Processing Record 42 | cidreira
# Processing Record 43 | east london
# Processing Record 44 | illoqqortoormiut
# City not found..Skipping.
# Processing Record 45 | bethel
# Processing Record 46 | brodick
# Processing Record 47 | atuona
# Processing Record 48 | mataura
# Processing Record 49 | zhitikara
# City not found..Skipping.
# Processing Record 50 | huaihua
# Processing Record 51 | vardo
# Processing Record 52 | iqaluit
# Processing Record 53 | tuy hoa
# Processing Record 54 | pontianak
# Processing Record 55 | thompson
# Processing Record 56 | zaraza
# Processing Record 57 | pacific grove
# Processing Record 58 | olden
# Processing Record 59 | viedma
# Processing Record 60 | waingapu
# Processing Record 61 | airai
# Processing Record 62 | boma
# Processing Record 63 | hasaki
# Processing Record 64 | sainte-anne-des-monts
# Processing Record 65 | kodiak
# Processing Record 66 | saint-philippe
# Processing Record 67 | palabuhanratu
# City not found..Skipping.
# Processing Record 68 | dumbrava
# Processing Record 69 | taolanaro
# City not found..Skipping.
# Processing Record 70 | mnogovershinnyy
# Processing Record 71 | kamyshla
# Processing Record 72 | manado
# Processing Record 73 | albanel
# Processing Record 74 | homa bay
# Processing Record 75 | takoradi
# Processing Record 76 | goderich
# Processing Record 77 | tooele
# Processing Record 78 | magistralnyy
# Processing Record 79 | victoria
# Processing Record 80 | novobessergenevka
# City not found..Skipping.
# Processing Record 81 | omsukchan
# Processing Record 82 | hinesburg
# Processing Record 83 | khatanga
# Processing Record 84 | tivaouane
# Processing Record 85 | teacapan
# Processing Record 86 | ponta do sol
# Processing Record 87 | nikolskoye
# Processing Record 88 | kiev
# Processing Record 89 | zhanatas
# City not found..Skipping.
# Processing Record 90 | pisco
# Processing Record 91 | yellowknife
# Processing Record 92 | bargal
# City not found..Skipping.
# Processing Record 93 | honiara
# Processing Record 94 | shpykiv
# City not found..Skipping.
# Processing Record 95 | formoso do araguaia
# City not found..Skipping.
# Processing Record 96 | rio grande
# Processing Record 97 | panjab
# Processing Record 98 | chumikan
# Processing Record 99 | pombas
# Processing Record 100 | vaini
# Processing Record 101 | butaritari
# Processing Record 102 | duku
# Processing Record 103 | salinas
# Processing Record 104 | zhovti vody
# Processing Record 105 | ostrovnoy
# Processing Record 106 | cabo san lucas
# Processing Record 107 | khuzhir
# Processing Record 108 | bontang
# Processing Record 109 | fort saint john
# City not found..Skipping.
# Processing Record 110 | padang
# Processing Record 111 | iskitim
# Processing Record 112 | inhambane
# Processing Record 113 | bulgan
# Processing Record 114 | nyaunglebin
# Processing Record 115 | clyde river
# Processing Record 116 | chieri
# Processing Record 117 | sentyabrskiy
# City not found..Skipping.
# Processing Record 118 | dikson
# Processing Record 119 | hobart
# Processing Record 120 | utiroa
# City not found..Skipping.
# Processing Record 121 | hermanus
# Processing Record 122 | tomatlan
# Processing Record 123 | ust-kuyga
# Processing Record 124 | mocuba
# Processing Record 125 | qingan
# City not found..Skipping.
# Processing Record 126 | kalemie
# Processing Record 127 | kapaa
# Processing Record 128 | bluff
# Processing Record 129 | sorland
# Processing Record 130 | aksarka
# Processing Record 131 | saint george
# Processing Record 132 | rio cauto
# Processing Record 133 | puerto ayora
# Processing Record 134 | fare
# Processing Record 135 | lompoc
# Processing Record 136 | garowe
# Processing Record 137 | mirabela
# Processing Record 138 | borogontsy
# Processing Record 139 | susuman
# Processing Record 140 | russell
# Processing Record 141 | cayenne
# Processing Record 142 | kaitangata
# Processing Record 143 | itatiaia
# Processing Record 144 | nadym
# Processing Record 145 | hohhot
# Processing Record 146 | pampa
# Processing Record 147 | coihaique
# Processing Record 148 | tawau
# Processing Record 149 | khalabat
# Processing Record 150 | atocha
# Processing Record 151 | yulara
# Processing Record 152 | hvide sande
# Processing Record 153 | moron
# Processing Record 154 | katsuura
# Processing Record 155 | goure
# Processing Record 156 | rawson
# Processing Record 157 | hammerfest
# Processing Record 158 | hamilton
# Processing Record 159 | leningradskiy
# Processing Record 160 | manaus
# Processing Record 161 | chokwe
# City not found..Skipping.
# Processing Record 162 | marcona
# City not found..Skipping.
# Processing Record 163 | gizo
# Processing Record 164 | port elizabeth
# Processing Record 165 | attawapiskat
# City not found..Skipping.
# Processing Record 166 | mayo
# Processing Record 167 | sioux lookout
# Processing Record 168 | craig
# Processing Record 169 | lorengau
# Processing Record 170 | cururupu
# Processing Record 171 | cockburn town
# Processing Record 172 | qaqortoq
# Processing Record 173 | sussex
# Processing Record 174 | mehamn
# Processing Record 175 | payo
# Processing Record 176 | parkes
# Processing Record 177 | surop
# City not found..Skipping.
# Processing Record 178 | lagoa
# Processing Record 179 | chuy
# Processing Record 180 | lavrentiya
# Processing Record 181 | pevek
# Processing Record 182 | kulykivka
# Processing Record 183 | ribeira grande
# Processing Record 184 | bathsheba
# Processing Record 185 | trairi
# Processing Record 186 | arraial do cabo
# Processing Record 187 | yanan
# City not found..Skipping.
# Processing Record 188 | olafsvik
# City not found..Skipping.
# Processing Record 189 | ossora
# Processing Record 190 | port lincoln
# Processing Record 191 | georgetown
# Processing Record 192 | barentsburg
# City not found..Skipping.
# Processing Record 193 | piacabucu
# Processing Record 194 | sidhauli
# Processing Record 195 | henties bay
# Processing Record 196 | skibbereen
# Processing Record 197 | novyy urengoy
# Processing Record 198 | avarua
# Processing Record 199 | tautira
# Processing Record 200 | walvis bay
# Processing Record 201 | ullapool
# Processing Record 202 | harnosand
# Processing Record 203 | ruteng
# Processing Record 204 | luganville
# Processing Record 205 | tuktoyaktuk
# Processing Record 206 | tsihombe
# City not found..Skipping.
# Processing Record 207 | kabalo
# Processing Record 208 | calvinia
# Processing Record 209 | geraldton
# Processing Record 210 | mount gambier
# Processing Record 211 | bilma
# Processing Record 212 | beringovskiy
# Processing Record 213 | aripuana
# Processing Record 214 | pese
# Processing Record 215 | shizunai
# Processing Record 216 | gander
# Processing Record 217 | progreso
# Processing Record 218 | buzmeyin
# Processing Record 219 | provideniya
# Processing Record 220 | berlevag
# Processing Record 221 | shelbyville
# Processing Record 222 | amberley
# Processing Record 223 | makinsk
# Processing Record 224 | kivsharivka
# Processing Record 225 | porto novo
# Processing Record 226 | kathu
# Processing Record 227 | mayumba
# Processing Record 228 | castro
# Processing Record 229 | maturin
# Processing Record 230 | kaeo
# Processing Record 231 | talcahuano
# Processing Record 232 | isangel
# Processing Record 233 | petropavlovsk-kamchatskiy
# Processing Record 234 | belushya guba
# City not found..Skipping.
# Processing Record 235 | severo-zadonsk
# Processing Record 236 | gunjur
# Processing Record 237 | durazno
# Processing Record 238 | los llanos de aridane
# Processing Record 239 | guadalajara
# Processing Record 240 | porto santo
# City not found..Skipping.
# Processing Record 241 | kamenskoye
# City not found..Skipping.
# Processing Record 242 | kargasok
# Processing Record 243 | songjianghe
# Processing Record 244 | barrow
# Processing Record 245 | kuala terengganu
# Processing Record 246 | upernavik
# Processing Record 247 | curaca
# Processing Record 248 | biu
# Processing Record 249 | sao gabriel da cachoeira
# Processing Record 250 | shirokiy
# Processing Record 251 | opuwo
# Processing Record 252 | male
# Processing Record 253 | ternate
# Processing Record 254 | alenquer
# Processing Record 255 | makakilo city
# Processing Record 256 | safford
# Processing Record 257 | palaiokhora
# City not found..Skipping.
# Processing Record 258 | kavaratti
# Processing Record 259 | ligayan
# Processing Record 260 | belogorsk
# Processing Record 261 | santiago de cao
# Processing Record 262 | roma
# Processing Record 263 | dunedin
# Processing Record 264 | yamada
# Processing Record 265 | yaan
# Processing Record 266 | qidong
# Processing Record 267 | pemba
# Processing Record 268 | kuminskiy
# Processing Record 269 | port-gentil
# Processing Record 270 | duncan
# Processing Record 271 | mahibadhoo
# Processing Record 272 | waidhofen
# Processing Record 273 | grand gaube
# Processing Record 274 | denpasar
# Processing Record 275 | booue
# Processing Record 276 | iona
# Processing Record 277 | bantry
# City not found..Skipping.
# Processing Record 278 | gravdal
# Processing Record 279 | belize
# City not found..Skipping.
# Processing Record 280 | karaul
# City not found..Skipping.
# Processing Record 281 | galiwinku
# City not found..Skipping.
# Processing Record 282 | nizhneyansk
# City not found..Skipping.
# Processing Record 283 | chalus
# Processing Record 284 | comodoro rivadavia
# Processing Record 285 | amderma
# City not found..Skipping.
# Processing Record 286 | michigan city
# Processing Record 287 | diamantino
# Processing Record 288 | verkhnechusovskiye gorodki
# Processing Record 289 | vila franca do campo
# Processing Record 290 | bambous virieux
# Processing Record 291 | cherskiy
# Processing Record 292 | san lorenzo
# Processing Record 293 | namibe
# Processing Record 294 | batagay-alyta
# Processing Record 295 | sokolka
# Processing Record 296 | maniitsoq
# Processing Record 297 | kot addu
# Processing Record 298 | port hawkesbury
# Processing Record 299 | jacksonville beach
# Processing Record 300 | kavieng
# Processing Record 301 | saskylakh
# Processing Record 302 | jiuquan
# Processing Record 303 | erzin
# Processing Record 304 | ilulissat
# Processing Record 305 | ketchikan
# Processing Record 306 | port washington
# Processing Record 307 | severo-kurilsk
# Processing Record 308 | verkhoyansk
# Processing Record 309 | sao joao da barra
# Processing Record 310 | mountain home
# Processing Record 311 | muana
# Processing Record 312 | yeniseysk
# Processing Record 313 | grand river south east
# City not found..Skipping.
# Processing Record 314 | torbay
# Processing Record 315 | chokurdakh
# Processing Record 316 | motygino
# Processing Record 317 | coahuayana
# Processing Record 318 | codrington
# Processing Record 319 | staritsa
# Processing Record 320 | peniche
# Processing Record 321 | dalton
# Processing Record 322 | foumban
# Processing Record 323 | palora
# Processing Record 324 | kruisfontein
# Processing Record 325 | paamiut
# Processing Record 326 | sayat
# Processing Record 327 | husavik
# Processing Record 328 | ha giang
# Processing Record 329 | tabou
# Processing Record 330 | mitsamiouli
# Processing Record 331 | mount isa
# Processing Record 332 | kalmunai
# Processing Record 333 | zhangye
# Processing Record 334 | moose factory
# Processing Record 335 | richards bay
# Processing Record 336 | portland
# Processing Record 337 | pathalgaon
# Processing Record 338 | bad kissingen
# Processing Record 339 | nouadhibou
# Processing Record 340 | atasu
# Processing Record 341 | cap malheureux
# Processing Record 342 | fasa
# Processing Record 343 | elko
# Processing Record 344 | flinders
# Processing Record 345 | hobyo
# Processing Record 346 | tual
# Processing Record 347 | kimbe
# Processing Record 348 | faanui
# Processing Record 349 | arman
# Processing Record 350 | oranjestad
# Processing Record 351 | mackay
# Processing Record 352 | nanortalik
# Processing Record 353 | matara
# Processing Record 354 | san cristobal
# Processing Record 355 | mys shmidta
# City not found..Skipping.
# Processing Record 356 | beyneu
# Processing Record 357 | weihai
# Processing Record 358 | udachnyy
# Processing Record 359 | nicoya
# Processing Record 360 | longyearbyen
# Processing Record 361 | heinola
# Processing Record 362 | saleaula
# City not found..Skipping.
# Processing Record 363 | roebourne
# Processing Record 364 | luderitz
# Processing Record 365 | mulchen
# Processing Record 366 | port alfred
# Processing Record 367 | california city
# Processing Record 368 | ngukurr
# City not found..Skipping.
# Processing Record 369 | hay river
# Processing Record 370 | port blair
# Processing Record 371 | salalah
# Processing Record 372 | college
# Processing Record 373 | hovd
# Processing Record 374 | portpatrick
# City not found..Skipping.
# Processing Record 375 | bar harbor
# Processing Record 376 | camacha
# Processing Record 377 | sanandaj
# Processing Record 378 | carmo do rio claro
# Processing Record 379 | talnakh
# Processing Record 380 | neyshabur
# Processing Record 381 | birjand
# Processing Record 382 | solnechnyy
# Processing Record 383 | sug-aksy
# City not found..Skipping.
# Processing Record 384 | diffa
# Processing Record 385 | preston
# Processing Record 386 | unity
# Processing Record 387 | san jose
# Processing Record 388 | usinsk
# Processing Record 389 | ambilobe
# Processing Record 390 | mongo
# Processing Record 391 | karachev
# Processing Record 392 | vila velha
# Processing Record 393 | lolua
# City not found..Skipping.
# Processing Record 394 | port lavaca
# Processing Record 395 | nguiu
# City not found..Skipping.
# Processing Record 396 | visby
# Processing Record 397 | huarmey
# Processing Record 398 | laukaa
# Processing Record 399 | yerbogachen
# Processing Record 400 | baculin
# Processing Record 401 | urucara
# Processing Record 402 | havoysund
# Processing Record 403 | naze
# Processing Record 404 | ancud
# Processing Record 405 | souillac
# Processing Record 406 | bowen
# Processing Record 407 | indaiatuba
# Processing Record 408 | mahon
# Processing Record 409 | saldanha
# Processing Record 410 | ilembula
# Processing Record 411 | abha
# Processing Record 412 | santa cruz
# Processing Record 413 | saint-pierre
# Processing Record 414 | paita
# Processing Record 415 | nakamura
# Processing Record 416 | chifeng
# Processing Record 417 | dakar
# Processing Record 418 | okhtyrka
# Processing Record 419 | montmagny
# Processing Record 420 | birao
# Processing Record 421 | ponta delgada
# Processing Record 422 | vostok
# Processing Record 423 | manuk mangkaw
# Processing Record 424 | meulaboh
# Processing Record 425 | rancho palos verdes
# Processing Record 426 | stokmarknes
# Processing Record 427 | kingori
# Processing Record 428 | khilok
# Processing Record 429 | praxedis guerrero
# Processing Record 430 | lendava
# Processing Record 431 | miri
# Processing Record 432 | tuatapere
# Processing Record 433 | champasak
# Processing Record 434 | chateaubelair
# Processing Record 435 | fortuna
# Processing Record 436 | inirida
# Processing Record 437 | avera
# Processing Record 438 | sisimiut
# Processing Record 439 | tarbagatay
# Processing Record 440 | svetlyy
# City not found..Skipping.
# Processing Record 441 | san patricio
# Processing Record 442 | fairbanks
# Processing Record 443 | tiksi
# Processing Record 444 | san pedro
# Processing Record 445 | nalut
# Processing Record 446 | charters towers
# Processing Record 447 | sakakah
# City not found..Skipping.
# Processing Record 448 | tura
# Processing Record 449 | xining
# Processing Record 450 | feijo
# Processing Record 451 | guerrero negro
# Processing Record 452 | kristiansund
# Processing Record 453 | katunino
# Processing Record 454 | lingao
# Processing Record 455 | koygorodok
# Processing Record 456 | roura
# Processing Record 457 | aketi
# Processing Record 458 | jalingo
# Processing Record 459 | dingle
# Processing Record 460 | wad rawah
# Processing Record 461 | shah alam
# Processing Record 462 | saint-francois
# Processing Record 463 | sayyan
# Processing Record 464 | trelew
# Processing Record 465 | komsomolskiy
# Processing Record 466 | firminy
# Processing Record 467 | paso de carrasco
# Processing Record 468 | belfast
# Processing Record 469 | santa marta de tormes
# Processing Record 470 | tumannyy
# City not found..Skipping.
# Processing Record 471 | yar-sale
# Processing Record 472 | lasa
# Processing Record 473 | rincon
# Processing Record 474 | samarai
# Processing Record 475 | sept-iles
# Processing Record 476 | new norfolk
# Processing Record 477 | la rioja
# Processing Record 478 | harper
# Processing Record 479 | wuning
# Processing Record 480 | bhongaon
# Processing Record 481 | prieska
# Processing Record 482 | alofi
# Processing Record 483 | porosozero
# Processing Record 484 | yinchuan
# Processing Record 485 | adrar
# Processing Record 486 | davlekanovo
# Processing Record 487 | paradwip
# City not found..Skipping.
# Processing Record 488 | ko samui
# Processing Record 489 | mandalgovi
# Processing Record 490 | tongzi
# Processing Record 491 | korla
# City not found..Skipping.
# Processing Record 492 | saint augustine
# Processing Record 493 | sola
# Processing Record 494 | klaksvik
# Processing Record 495 | madera
# Processing Record 496 | saucillo
# Processing Record 497 | belmonte
# Processing Record 498 | chernyakhovsk
# Processing Record 499 | morehead
# Processing Record 500 | hami
# Processing Record 501 | tall kayf
# Processing Record 502 | agbannawag
# Processing Record 503 | narrabri
# Processing Record 504 | bangaon
# Processing Record 505 | aybak
# City not found..Skipping.
# Processing Record 506 | juybar
# Processing Record 507 | kaspi
# Processing Record 508 | khani
# Processing Record 509 | turukhansk
# Processing Record 510 | galgani
# City not found..Skipping.
# Processing Record 511 | northam
# Processing Record 512 | wanning
# Processing Record 513 | travagliato
# Processing Record 514 | malatya
# City not found..Skipping.
# Processing Record 515 | kushima
# Processing Record 516 | reconquista
# Processing Record 517 | pemangkat
# City not found..Skipping.
# Processing Record 518 | haibowan
# City not found..Skipping.
# Processing Record 519 | bichura
# Processing Record 520 | pizarro
# Processing Record 521 | zhigansk
# Processing Record 522 | nortelandia
# Processing Record 523 | mungwi
# Processing Record 524 | tabiauea
# City not found..Skipping.
# Processing Record 525 | ngunguru
# Processing Record 526 | ban nahin
# Processing Record 527 | ambon
# Processing Record 528 | todos santos
# Processing Record 529 | faya
# Processing Record 530 | itaituba
# Processing Record 531 | bambanglipuro
# Processing Record 532 | dale
# Processing Record 533 | popondetta
# Processing Record 534 | constitucion
# Processing Record 535 | banda aceh
# Processing Record 536 | hihifo
# City not found..Skipping.
# Processing Record 537 | sao jose da coroa grande
# Processing Record 538 | gallup
# Processing Record 539 | kahului
# Processing Record 540 | nelson bay
# Processing Record 541 | wahran
# City not found..Skipping.
# Processing Record 542 | hofn
# Processing Record 543 | hoquiam
# Processing Record 544 | kaupanger
# Processing Record 545 | malwan
# City not found..Skipping.
# Processing Record 546 | lakselv
# Processing Record 547 | eureka
# Processing Record 548 | liliongan
# Processing Record 549 | serenje
# Processing Record 550 | vinh
# Processing Record 551 | springbok
# Processing Record 552 | egvekinot
# Processing Record 553 | margate
# Processing Record 554 | edd
# Processing Record 555 | rzhev
# Processing Record 556 | north bend
# Processing Record 557 | changji
# Processing Record 558 | ondal
# City not found..Skipping.
# Processing Record 559 | tambacounda
# Processing Record 560 | nenjiang
# Processing Record 561 | broken hill
# Processing Record 562 | kalianget
# Processing Record 563 | sao filipe
# Processing Record 564 | narsaq
# Processing Record 565 | chilca
# Processing Record 566 | toyonaka
# Processing Record 567 | sri aman
# Processing Record 568 | kyra
# City not found..Skipping.
# Processing Record 569 | torbat-e jam
# Processing Record 570 | ixtlahuacan del rio
# Processing Record 571 | nacala
# Processing Record 572 | maraa
# Processing Record 573 | alexandria
# Processing Record 574 | saint-georges
# Processing Record 575 | mudyuga
# City not found..Skipping.
# Processing Record 576 | sydney
# Processing Record 577 | aleksandrovsk-sakhalinskiy
# Processing Record 578 | kaka
# Processing Record 579 | doctor pedro p. pena
# City not found..Skipping.
# Processing Record 580 | bunol
# Processing Record 581 | kasempa
# Processing Record 582 | oranjemund
# Processing Record 583 | acari
# Processing Record 584 | high level
# Processing Record 585 | qax
# Processing Record 586 | poum
# Processing Record 587 | mafeteng
# Processing Record 588 | wattegama
# Processing Record 589 | dandong
# Processing Record 590 | genthin
# Processing Record 591 | port macquarie
# Processing Record 592 | iralaya
# Processing Record 593 | ciechanow
# Processing Record 594 | quatre cocos
# Processing Record 595 | chagoda
# Processing Record 596 | beloha
# Processing Record 597 | san carlos de bariloche
# Processing Record 598 | sibolga
# Processing Record 599 | letnyaya stavka
# Processing Record 600 | vaitape
# Processing Record 601 | nome
# Processing Record 602 | samusu
# City not found..Skipping.
# Processing Record 603 | kem
# Processing Record 604 | hare bay
# Processing Record 605 | eyl
# Processing Record 606 | mombetsu
# Processing Record 607 | esperance
# Processing Record 608 | vila
# Processing Record 609 | linchuan
# City not found..Skipping.
# Processing Record 610 | bonavista
# Processing Record 611 | frankenburg
# Processing Record 612 | bousso
# City not found..Skipping.
# Processing Record 613 | san rafael
# Processing Record 614 | manali
# Processing Record 615 | safaqis
# City not found..Skipping.
# Processing Record 616 | salina
# Processing Record 617 | coquimbo
# Processing Record 618 | ewa beach
# Processing Record 619 | falaleu
# City not found..Skipping.
# Processing Record 620 | wahiawa
# Processing Record 621 | elda
# Processing Record 622 | touros
# Processing Record 623 | kinshasa
# Processing Record 624 | chigorodo
# City not found..Skipping.
# Processing Record 625 | campo verde
# Processing Record 626 | kawana waters
# City not found..Skipping.
# Processing Record 627 | monte carmelo
# Processing Record 628 | matranovak
# Processing Record 629 | san quintin
# Processing Record 630 | vieques
# Processing Record 631 | espanola
# Processing Record 632 | buraydah
# Processing Record 633 | ixtapa
# Processing Record 634 | calama
# Processing Record 635 | lukuledi
# Processing Record 636 | rockland
# Processing Record 637 | muros
# Processing Record 638 | nemuro
# Processing Record 639 | shchelyayur
# City not found..Skipping.
# Processing Record 640 | martapura
# Processing Record 641 | pyay
# Processing Record 642 | karasjok
# Processing Record 643 | baykit
# Processing Record 644 | vestmannaeyjar
# Processing Record 645 | tiarei
# Processing Record 646 | shakawe
# Processing Record 647 | ati
# Processing Record 648 | ca mau
# Processing Record 649 | kuche
# City not found..Skipping.
# Processing Record 650 | bage
# Processing Record 651 | caravelas
# Processing Record 652 | san-pedro
# Processing Record 653 | mangochi

# %%
# Create data frame
cities_df = pd.DataFrame({"City": city, "Cloudiness": clouds, "Country": country, "Date": dt, 
                              "Humidity": humidity, "Lat": lat, "Lng": lon, "Max Temp": temp_max, 
                             "Wind Speed": speed})
cities_df.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  mangochi          90      US  1554427798        34  61.58 -149.44
# 1  mangochi          20      US  1554427643        57  19.71 -155.08
# 2  mangochi          40      ZA  1554427929        76 -33.93   18.42
# 3  mangochi           0      AU  1554427809        35 -33.64  115.35
# 4  mangochi          12      ZA  1554428059        72 -30.97   22.13
#
#    Max Temp  Wind Speed
# 0   278.710        5.10
# 1   299.150        4.60
# 2   288.150        4.10
# 3   289.260        3.36
# 4   282.352        6.96

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.count()
# Out:
# City          581
# Cloudiness    581
# Country       581
# Date          581
# Humidity      581
# Lat           581
# Lng           581
# Max Temp      581
# Wind Speed    581
# dtype: int64

# %%
cities_df.to_csv('City_Data.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], marker="o", linewidth=0.4)

# Incorporate the other graph properties
plt.title("Fig. 1 City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City_lat_Max_temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_df["Lat"], cities_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Fig. 2 City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City_lat_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Fig. 3 City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City_lat_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Fig. 4 City Latitude vs. Wind Speed (8/22/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City_lat_Wind_speed.png")

# Show plot
plt.show()

# %% [markdown]
#  According to Fig. 1, max temperature (F) rises at a latitude of 0.
#  According to Fig. 2, latitude has no effect on humidity.
#  According to Fig. 3, latitude has no effect on cloudiness.
#  According to Fig. 4, latitude has no effect on wind speed.
